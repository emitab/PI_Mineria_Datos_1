# %%
# Importar librerías
import pandas as pd

# Cargar el dataset
df = pd.read_json("../data/raw/streaming_users_dirty.json")

# Primeras filas
df.head()

# %%
# Cantidad de filas y columnas
df.shape

# %%
df.info()

# %%
df.isnull().sum()

# %% [markdown]
# #Diccionario
# - user_id = identificador de usuario
# - age = edad
# - subscription_plan = plan de suscripcion
# - monthly_watch_time_mins = minutos vistos en el mes
# - country = pais
# - favorite_genre = genero favorito
# - last_login_date = fecha de ultimo inicio de sesion
# - customer_support_tickets = tickets de atencion al cliente
#
#
# # Interpretacion
#
# - 8160 filas, 8 columnas.
# - En columnas `"monthly_watch_time_mins"` (193), `"favorite_genre"`(240) y `"last_login_date"`(384) hay presencia de datos nulos, sumando un total de 817.
# - La columna `"last_login_date"` tiene un tipo de dato erroneo (esta en object, debe ser date)

# %%
df.describe()

# %% [markdown]
# # Valores imposibles
# - Valor minimo de `"age"` y `"monthly_watch_time_mins"` son negativos, cuando no es posible.
# - Valor maximo de `"age"`, `"monthly_watch_time_mins"` tienen valores imposibles.
# - Maximo de `"last_login_date"` es un dato poco probable teniendo en cuenta la media.
#
# - Analisis de medidas se realizan luego de procesamiento y limpieza de la base de datos.
